# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Here are 10 random words:
# ember, sunflower, quiver, lattice, drift, velvet, peregrine, espresso, tumble, wisps

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=678, prompt_tokens=24, total_tokens=702, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=640, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# Sure. Here are 10 random words:
#
# 1) ember
# 2) zephyr
# 3) lantern
# 4) quiver
# 5) mosaic
# 6) s equal? (Oops) — let me replace.
#
# Let's provide clean list:
#
# 1) ember
# 2) zephyr
# 3) lantern
# 4) quiver
# 5) mosaic
# 6) drift
# 7) coral
# 8) eclipse
# 9) harbor
# 10) velvet
#
# If you want a different set or a specific category, tell me.

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=114, prompt_tokens=24, total_tokens=138, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)

# %%
response.usage

# %% [markdown]
# ### Google genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant",
              "can you print 15 random words?"]
)

print(response.text)
# Out:
# Here are 15 random words for you:
#
# 1.  bicycle
# 2.  shadow
# 3.  curious
# 4.  whisper
# 5.  journey
# 6.  fragile
# 7.  ocean
# 8.  laughter
# 9.  enormous
# 10. twilight
# 11. vibrant
# 12. memory
# 13. ancient
# 14. delicate
# 15. melody

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"}
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Caramel
# 4. Banana
# 5. Guitar
# 6. Snowflake
# 7. Perfume
# 8. Llama
# 9. Coffee
# 10. Bicycle
# 11. Pineapple
# 12. Starfish
# 13. Violin
# 14. Chocolate
# 15. Submarine
# 16. Butterfly
# 17. Hockey
# 18. Parakeet
# 19. Tornado
# 20. Microscope
